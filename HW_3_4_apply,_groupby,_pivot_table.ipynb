# %% [markdown]
# <a href="https://colab.research.google.com/github/sheinviktoriia/Data-analyst-home-works-/blob/main/HW_3_4_apply%2C_groupby%2C_pivot_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('drive/MyDrive/supermarket_sales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.groupby('Branch')['gross income'].sum()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# Найбільший прибуток у філіалу С.

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.groupby(['Branch', 'City'])['gross income'].sum()
# Out:
# Branch  City
# A       Yangon       5057.1605
# B       Mandalay     5057.0320
# C       Naypyitaw    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = df.pivot_table(index = 'Branch', columns = 'Product line', aggfunc = 'size')
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].idxmax()
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# 1. Яку кількість товарів по категоріях купують в різних містах.

# %%
df.groupby(['Product line', 'City']).size()
# Out:
# Product line            City
# Electronic accessories  Mandalay     55
#                         Naypyitaw    55
#                         Yangon       60
# Fashion accessories     Mandalay     62
#                         Naypyitaw    65
#                         Yangon       51
# Food and beverages      Mandalay     50
#                         Naypyitaw    66
#                         Yangon       58
# Health and beauty       Mandalay     53
#                         Naypyitaw    52
#                         Yangon       47
# Home and lifestyle      Mandalay     50
#                         Naypyitaw    45
#                         Yangon       65
# Sports and travel       Mandalay     62
#                         Naypyitaw    45
#                         Yangon       59
# dtype: int64

# %% [markdown]
# У містах, де категорії певних товарів продаються гірше, ніж в інших, потрібно проаналізувати чому це відбувається і, наприклад, запустити промо-акції чи переглянути асортимент товару і доповнити, або замінити. Наприклад, у місті Mandalay товари категорії Sports and travel продаються набагато краще, ніж в місті Naypyitaw. Можливо, це рекреаційна зона і сезонні пропозиції можуть залучити ще більше клієнтів.

# %% [markdown]
# 2. Який відсоток покупців користуються картою клієнта

# %%
df[['Gender', 'Customer type']].value_counts(normalize=True)
# Out:
# Gender  Customer type
# Female  Member           0.261
# Male    Normal           0.259
# Female  Normal           0.240
# Male    Member           0.240
# dtype: float64

# %% [markdown]
# Власниками карти клієнта є перевано жінки, для заохочення покупок, на товари, які користуються більшим опитом у жінок можна зробити спеціальні пропозиціі з картою клієнта.

# %% [markdown]
# 3. Який метод розрахунку найчастіше використовують покупці з картою клієнта, а яким користуються покупці без карти?

# %%
df.pivot_table(index = 'Customer type', columns = 'Payment', values = 'Total', aggfunc = 'sum')
# Out:
# Payment              Cash  Credit card    Ewallet
# Customer type
# Member         54661.0155   57771.4725  51790.956
# Normal         57545.5545   42995.5995  58202.151

# %% [markdown]
# Для залучення нових членів до системи лояльності (видача карти клієнта), можна нараховувати кеш-бек за розрахунок електронним гаманцем.
